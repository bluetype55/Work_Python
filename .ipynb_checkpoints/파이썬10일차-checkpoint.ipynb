# %%
import requests
from tqdm import tqdm
import pandas as pd
import numpy as np
import time
import my_utils as mu
import math
import random
import imp
import matplotlib.pyplot as plt
imp.reload(mu)
tqdm.pandas()

# %%
mu.db_open()
df = mu.oracle_execute('select * from lol_datas')
mu.oracle_close()
# Out:
# oracle open!
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# '오라클 닫힘!'

# %%
conn= mu.connect_mysql('icia')
df = pd.DataFrame(mu.mysql_execute_dict('select * from lol_datas',conn))
conn.close()

# %%
df
# Out:
#               gameId  gameDuration     gameVersion      summonerName  \
# 0      KR_6306333604           521   13.1.487.9641            Kim 종원
# 1      KR_6306333604           521   13.1.487.9641               건 요
# 2      KR_6306333604           521   13.1.487.9641            첫눈을 빌려
# 3      KR_6306333604           521   13.1.487.9641             Kb999
# 4      KR_6306333604           521   13.1.487.9641  구울구울구울구울구울구울구울구울
# ...              ...           ...             ...               ...
# 79175  KR_6258040492          2440  12.23.483.5208        Jeongsunha
# 79176  KR_6258040492          2440  12.23.483.5208               구철통
# 79177  KR_6258040492          2440  12.23.483.5208             탈론 명인
# 79178  KR_6258040492          2440  12.23.483.5208             149cm
# 79179  KR_6258040492          2440  12.23.483.5208          아이언 구렁텅이
#
#        summonerLevel  participantId championName  champExperience  \
# 0                193              1        Garen             2175
# 1                103              2      Kindred             2584
# 2                187              3         Ekko             3658
# 3                355              4        Kaisa             2480
# 4                 49              5   Blitzcrank             2292
# ...              ...            ...          ...              ...
# 79175             40              6         Sett            18967
# 79176            258              7       Lillia            21639
# 79177             91              8        Akali            17250
# 79178            155              9        Varus            18100
# 79179            295             10      Morgana            14908
#
#       teamPosition  teamId  ...  g_16  g_17  g_18  g_19   g_20   g_21   g_22  \
# 0              TOP     100  ...     0     0     0     0      0      0      0
# 1           JUNGLE     100  ...     0     0     0     0      0      0      0
# 2           MIDDLE     100  ...     0     0     0     0      0      0      0
# 3           BOTTOM     100  ...     0     0     0     0      0      0      0
# 4          UTILITY     100  ...     0     0     0     0      0      0      0
# ...            ...     ...  ...   ...   ...   ...   ...    ...    ...    ...
# 79175          TOP     200  ...  6208  6352  6583  6734   6891   7083   8265
# 79176       JUNGLE     200  ...  8627  8812  9087  9519  10097  10324  10640
# 79177       MIDDLE     200  ...  4502  4624  5546  5679   5864   5987   6345
# 79178       BOTTOM     200  ...  4670  4925  5260  5529   5729   6018   6387
# 79179      UTILITY     200  ...  3449  3649  3913  4185   4386   4554   4744
#
#         g_23   g_24   g_25
# 0          0      0      0
# 1          0      0      0
# 2          0      0      0
# 3          0      0      0
# 4          0      0      0
# ...      ...    ...    ...
# 79175   8527   9012   9176
# 79176  11367  11738  11861
# 79177   7367   7490   7647
# 79178   6969   7267   7644
# 79179   4935   5194   5376
#
# [79180 rows x 37 columns]

# %%
my_df = df[df.gameId =='KR_6258040492']

# %%
my_df
# Out:
#               gameId  gameDuration     gameVersion      summonerName  \
# 79170  KR_6258040492          2440  12.23.483.5208  sherlocklovejohn
# 79171  KR_6258040492          2440  12.23.483.5208              염오쩌둥
# 79172  KR_6258040492          2440  12.23.483.5208       anather5337
# 79173  KR_6258040492          2440  12.23.483.5208         jungwon99
# 79174  KR_6258040492          2440  12.23.483.5208             롤린이떴다
# 79175  KR_6258040492          2440  12.23.483.5208        Jeongsunha
# 79176  KR_6258040492          2440  12.23.483.5208               구철통
# 79177  KR_6258040492          2440  12.23.483.5208             탈론 명인
# 79178  KR_6258040492          2440  12.23.483.5208             149cm
# 79179  KR_6258040492          2440  12.23.483.5208          아이언 구렁텅이
#
#        summonerLevel  participantId championName  champExperience  \
# 79170             91              1     Malphite            15379
# 79171            195              2       Graves            18738
# 79172            219              3        Yasuo            14240
# 79173            239              4       Draven            15717
# 79174            181              5          Lux            13278
# 79175             40              6         Sett            18967
# 79176            258              7       Lillia            21639
# 79177             91              8        Akali            17250
# 79178            155              9        Varus            18100
# 79179            295             10      Morgana            14908
#
#       teamPosition  teamId  ...  g_16  g_17  g_18  g_19   g_20   g_21   g_22  \
# 79170          TOP     100  ...  5516  5838  6154  6326   6518   6970   7218
# 79171       JUNGLE     100  ...  5659  6526  7384  8037   8426   8775   9002
# 79172       MIDDLE     100  ...  6910  7466  7791  8359   8522   8787   8909
# 79173       BOTTOM     100  ...  6558  7204  7586  7883   8212   8691   8814
# 79174      UTILITY     100  ...  4458  5392  5875  6107   6328   6648   6837
# 79175          TOP     200  ...  6208  6352  6583  6734   6891   7083   8265
# 79176       JUNGLE     200  ...  8627  8812  9087  9519  10097  10324  10640
# 79177       MIDDLE     200  ...  4502  4624  5546  5679   5864   5987   6345
# 79178       BOTTOM     200  ...  4670  4925  5260  5529   5729   6018   6387
# 79179      UTILITY     200  ...  3449  3649  3913  4185   4386   4554   4744
#
#         g_23   g_24   g_25
# 79170   7341   7463   7710
# 79171   9187   9660  10493
# 79172   9081   9203   9963
# 79173   9523   9751  10380
# 79174   7128   7310   7633
# 79175   8527   9012   9176
# 79176  11367  11738  11861
# 79177   7367   7490   7647
# 79178   6969   7267   7644
# 79179   4935   5194   5376
#
# [10 rows x 37 columns]

# %%
my_df = my_df[['gameId','summonerName','championName','teamPosition','teamId','win','kills','deaths','assists','g_14']]

# %%
my_df
# Out:
#               gameId      summonerName championName teamPosition  teamId  \
# 79170  KR_6258040492  sherlocklovejohn     Malphite          TOP     100
# 79171  KR_6258040492              염오쩌둥       Graves       JUNGLE     100
# 79172  KR_6258040492       anather5337        Yasuo       MIDDLE     100
# 79173  KR_6258040492         jungwon99       Draven       BOTTOM     100
# 79174  KR_6258040492             롤린이떴다          Lux      UTILITY     100
# 79175  KR_6258040492        Jeongsunha         Sett          TOP     200
# 79176  KR_6258040492               구철통       Lillia       JUNGLE     200
# 79177  KR_6258040492             탈론 명인        Akali       MIDDLE     200
# 79178  KR_6258040492             149cm        Varus       BOTTOM     200
# 79179  KR_6258040492          아이언 구렁텅이      Morgana      UTILITY     200
#
#          win  kills  deaths  assists  g_14
# 79170   True      6      11       18  4395
# 79171   True      8       8       11  4485
# 79172   True     10      11       14  5752
# 79173   True     13       7        8  6087
# 79174   True      5       8       20  3962
# 79175  False     15       8       16  4707
# 79176  False      8       4       27  7783
# 79177  False     10      13        8  3967
# 79178  False     10       8       10  4260
# 79179  False      2       9       14  3108

# %%
blue_team = my_df[my_df.TEAMID ==100]
red_team = my_df[my_df.TEAMID ==200]

# %%
blue_team
# Out:
#              GAMEID SUMMONERNAME CHAMPIONNAME TEAMPOSITION  TEAMID    WIN  \
# 2988  KR_6383066191       원탑모델도상        Teemo          TOP     100  False
# 2989  KR_6383066191        닫힌 서랍     Nocturne       JUNGLE     100  False
# 2990  KR_6383066191        새콤한딸기        Akali       MIDDLE     100  False
# 2991  KR_6383066191  kokopamjjag         Sett       BOTTOM     100  False
# 2992  KR_6383066191         보스티모        Senna      UTILITY     100  False
#
#       KILLS  DEATHS  ASSISTS  G_14
# 2988      0       1        0  2893
# 2989      4       2        1  5183
# 2990      1       4        1  4044
# 2991      0       4        1  3631
# 2992      2       4        1  4351

# %%
red_team = red_team.drop(columns=['TEAMID','WIN']).rename(columns = {'SUMMONERNAME':'red_SUMMONERNAME','CHAMPIONNAME':'red_CHAMPIONNAME','KILLS':'red_KILLS','DEATHS':'red_DEATHS','ASSISTS':'red_ASSISTS','G_14':'red_G_14'})

# %%
blue_team.sort_values(by=['G_14'],ascending=False)
# Out:
#              GAMEID SUMMONERNAME CHAMPIONNAME TEAMPOSITION  TEAMID    WIN  \
# 2989  KR_6383066191        닫힌 서랍     Nocturne       JUNGLE     100  False
# 2992  KR_6383066191         보스티모        Senna      UTILITY     100  False
# 2990  KR_6383066191        새콤한딸기        Akali       MIDDLE     100  False
# 2991  KR_6383066191  kokopamjjag         Sett       BOTTOM     100  False
# 2988  KR_6383066191       원탑모델도상        Teemo          TOP     100  False
#
#       KILLS  DEATHS  ASSISTS  G_14
# 2989      4       2        1  5183
# 2992      2       4        1  4351
# 2990      1       4        1  4044
# 2991      0       4        1  3631
# 2988      0       1        0  2893

# %%
red_team.sort_values(by=['red_G_14'],ascending=False)
# Out:
#              GAMEID red_SUMMONERNAME red_CHAMPIONNAME TEAMPOSITION  red_KILLS  \
# 2996  KR_6383066191            부천난봉꾼      MissFortune       BOTTOM          3
# 2995  KR_6383066191             크린넥스            Annie       MIDDLE          5
# 2994  KR_6383066191        민지의 서폿생활             Elise       JUNGLE          5
# 2993  KR_6383066191         T1 jeus2            Kayle          TOP          1
# 2997  KR_6383066191           질병게임체험            Swain      UTILITY          1
#
#       red_DEATHS  red_ASSISTS  red_G_14
# 2996           2            1      5865
# 2995           3            0      5230
# 2994           0            2      5099
# 2993           1            3      5060
# 2997           1            3      4780

# %%
game_stat_df = pd.merge(blue_team,red_team,on=['GAMEID','TEAMPOSITION'])

# %%
game_stat_df2.astype(dtype='int64',errors = 'ignore')
# Out:
#           GAMEID SUMMONERNAME CHAMPIONNAME TEAMPOSITION  TEAMID    WIN  KILLS  \
# 0  KR_6383066191       원탑모델도상        Teemo          TOP     100  False      0
# 1  KR_6383066191        닫힌 서랍     Nocturne       JUNGLE     100  False      4
# 2  KR_6383066191        새콤한딸기        Akali       MIDDLE     100  False      1
# 3  KR_6383066191  kokopamjjag         Sett       BOTTOM     100  False      0
# 4  KR_6383066191         보스티모        Senna      UTILITY     100  False      2
#
#    DEATHS  ASSISTS  G_14 red_SUMMONERNAME red_CHAMPIONNAME  red_KILLS  \
# 0       1        0  2893         T1 jeus2            Kayle          1
# 1       2        1  5183        민지의 서폿생활             Elise          5
# 2       4        1  4044             크린넥스            Annie          5
# 3       4        1  3631            부천난봉꾼      MissFortune          3
# 4       4        1  4351           질병게임체험            Swain          1
#
#    red_DEATHS  red_ASSISTS  red_G_14  lane_win
# 0           1            3      5060   red_win
# 1           0            2      5099  blue_win
# 2           3            0      5230   red_win
# 3           2            1      5865   red_win
# 4           1            3      4780   red_win

# %%
def win(x):
    if x.G_14 < x.red_G_14:
        return 'red_win'
    if x.G_14 > x.red_G_14:
        return 'blue_win'
    else: return 'draw'

# %%
game_stat_df['lane_win']=game_stat_df.apply(lambda x: win(x),axis=1)

# %%
my_df2 = df[['gameId','championName','teamId','teamPosition','win','g_14']]

# %%
my_df2['win']=my_df2['win'].apply(lambda x:1 if x=='True' else 0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6292\3792738749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_df2['win']=my_df2['win'].apply(lambda x:1 if x=='True' else 0)

# %%
my_df2
# Out:
#               gameId championName  teamId teamPosition  win  g_14
# 0      KR_6306333604        Garen     100          TOP    0     0
# 1      KR_6306333604      Kindred     100       JUNGLE    0     0
# 2      KR_6306333604         Ekko     100       MIDDLE    0     0
# 3      KR_6306333604        Kaisa     100       BOTTOM    0     0
# 4      KR_6306333604   Blitzcrank     100      UTILITY    0     0
# ...              ...          ...     ...          ...  ...   ...
# 79175  KR_6258040492         Sett     200          TOP    0  4707
# 79176  KR_6258040492       Lillia     200       JUNGLE    0  7783
# 79177  KR_6258040492        Akali     200       MIDDLE    0  3967
# 79178  KR_6258040492        Varus     200       BOTTOM    0  4260
# 79179  KR_6258040492      Morgana     200      UTILITY    0  3108
#
# [79180 rows x 6 columns]

# %%
cnt_df = my_df2.groupby(['championName','teamPosition'])[['win']].count().rename(columns={'win':'cnt'})

# %%
cnt_df
# Out:
#                            cnt
# championName teamPosition
# Aatrox       BOTTOM          2
#              JUNGLE          4
#              MIDDLE         52
#              TOP           639
#              UTILITY         5
# ...                        ...
# Zyra         BOTTOM          3
#              JUNGLE          1
#              MIDDLE          8
#              TOP             3
#              UTILITY       212
#
# [729 rows x 1 columns]

# %%
win_df = my_df2.groupby(['CHAMPIONNAME','TEAMPOSITION'])[['WIN']].sum()

# %%
win_df
# Out:
#                            WIN
# CHAMPIONNAME TEAMPOSITION
# Aatrox       TOP             3
# Ahri         MIDDLE         10
#              UTILITY         1
# Akali        MIDDLE          6
#              TOP             6
# ...                        ...
# Zilean       MIDDLE          1
#              UTILITY         3
# Zoe          MIDDLE          5
#              UTILITY         1
# Zyra         UTILITY         7
#
# [335 rows x 1 columns]

# %%
cnt_win_df = pd.merge(cnt_df,win_df,on=['CHAMPIONNAME','TEAMPOSITION'])

# %%
cnt_win_df
# Out:
#                            CNT  WIN
# CHAMPIONNAME TEAMPOSITION
# Aatrox       TOP            12    3
# Ahri         MIDDLE         14   10
#              UTILITY         1    1
# Akali        MIDDLE         21    6
#              TOP            13    6
# ...                        ...  ...
# Zilean       MIDDLE          1    1
#              UTILITY         5    3
# Zoe          MIDDLE          8    5
#              UTILITY         2    1
# Zyra         UTILITY        12    7
#
# [335 rows x 2 columns]

# %%
cnt_win_df['win_rate']=round(cnt_win_df.WIN / cnt_win_df.CNT,4)

# %%
cnt_win_df
# Out:
#                            CNT  WIN  win_rate
# CHAMPIONNAME TEAMPOSITION
# Aatrox       TOP            12    3    0.2500
# Ahri         MIDDLE         14   10    0.7143
#              UTILITY         1    1    1.0000
# Akali        MIDDLE         21    6    0.2857
#              TOP            13    6    0.4615
# ...                        ...  ...       ...
# Zilean       MIDDLE          1    1    1.0000
#              UTILITY         5    3    0.6000
# Zoe          MIDDLE          8    5    0.6250
#              UTILITY         2    1    0.5000
# Zyra         UTILITY        12    7    0.5833
#
# [335 rows x 3 columns]

# %%
cnt_win_df.sort_values(by=['win_rate'],ascending=False)[:60]
# Out:
#                            CNT  WIN  win_rate
# CHAMPIONNAME TEAMPOSITION
# Neeko        TOP             1    1    1.0000
# Shen         UTILITY         1    1    1.0000
# Renata       UTILITY         3    3    1.0000
# Sejuani      TOP             1    1    1.0000
#              UTILITY         1    1    1.0000
# Senna        BOTTOM          1    1    1.0000
# Seraphine    BOTTOM          1    1    1.0000
# Kled         MIDDLE          1    1    1.0000
# Shen         JUNGLE          1    1    1.0000
# Shyvana      MIDDLE          1    1    1.0000
# Graves       UTILITY         1    1    1.0000
# Singed       TOP             4    4    1.0000
# Evelynn      TOP             1    1    1.0000
# Sion         BOTTOM          1    1    1.0000
# Draven       TOP             1    1    1.0000
# Swain        BOTTOM          1    1    1.0000
#              TOP             1    1    1.0000
# Sylas        UTILITY         1    1    1.0000
# Rammus       TOP             1    1    1.0000
# Gwen         JUNGLE          1    1    1.0000
# Teemo        JUNGLE          2    2    1.0000
# Malzahar     UTILITY         1    1    1.0000
# LeeSin       UTILITY         2    2    1.0000
# Lucian       MIDDLE          1    1    1.0000
# Kayle        MIDDLE          1    1    1.0000
# Lulu         MIDDLE          1    1    1.0000
# Malphite     UTILITY         1    1    1.0000
# Karthus      JUNGLE          1    1    1.0000
# Kalista      UTILITY         2    2    1.0000
# Jhin         MIDDLE          1    1    1.0000
# Poppy        TOP             3    3    1.0000
# Neeko        UTILITY         1    1    1.0000
# Nocturne     TOP             2    2    1.0000
# Jax          MIDDLE          1    1    1.0000
#              JUNGLE          1    1    1.0000
# JarvanIV     UTILITY         1    1    1.0000
# Olaf         JUNGLE          2    2    1.0000
# Orianna      BOTTOM          1    1    1.0000
# Taliyah      UTILITY         1    1    1.0000
# Sett         UTILITY         1    1    1.0000
# Xerath       BOTTOM          1    1    1.0000
# Zilean       MIDDLE          1    1    1.0000
# Velkoz       MIDDLE          1    1    1.0000
# Zac          UTILITY         1    1    1.0000
# Ziggs        BOTTOM          1    1    1.0000
# AurelionSol  BOTTOM          1    1    1.0000
# Viktor       TOP             1    1    1.0000
# Volibear     JUNGLE          1    1    1.0000
# Twitch       JUNGLE          1    1    1.0000
# Tryndamere   MIDDLE          1    1    1.0000
# Trundle      UTILITY         1    1    1.0000
#              JUNGLE          2    2    1.0000
# Twitch       BOTTOM          1    1    1.0000
# Viego        MIDDLE          1    1    1.0000
# Caitlyn      TOP             1    1    1.0000
# Ahri         UTILITY         1    1    1.0000
# Camille      MIDDLE          1    1    1.0000
# Heimerdinger UTILITY         6    5    0.8333
# Illaoi       TOP            14   11    0.7857
# Maokai       TOP             4    3    0.7500

# %%
cnt_win_df.sort_values(by=['CNT'],ascending=False)[:60]
# Out:
#                            CNT  WIN  win_rate
# CHAMPIONNAME TEAMPOSITION
# LeeSin       JUNGLE         81   49    0.6049
# Ezreal       BOTTOM         74   34    0.4595
# Kaisa        BOTTOM         71   41    0.5775
# Jinx         BOTTOM         66   26    0.3939
# Thresh       UTILITY        57   24    0.4211
# Caitlyn      BOTTOM         52   22    0.4231
# Xayah        BOTTOM         49   26    0.5306
# Jhin         BOTTOM         48   27    0.5625
# JarvanIV     JUNGLE         45   29    0.6444
# Lux          UTILITY        43   17    0.3953
# Blitzcrank   UTILITY        43   20    0.4651
# Varus        BOTTOM         37   18    0.4865
# Nautilus     UTILITY        35   22    0.6286
# Sylas        JUNGLE         35   14    0.4000
# Yone         MIDDLE         33   21    0.6364
# AurelionSol  MIDDLE         31   21    0.6774
# Vi           JUNGLE         31   17    0.5484
# Samira       BOTTOM         31   12    0.3871
# Jayce        TOP            30   17    0.5667
# Ashe         UTILITY        28   15    0.5357
# Zed          MIDDLE         28   14    0.5000
# Yuumi        UTILITY        27   15    0.5556
# Yasuo        MIDDLE         26    8    0.3077
# Jax          TOP            26   11    0.4231
# Xerath       UTILITY        25   12    0.4800
# Veigar       BOTTOM         25   16    0.6400
# Nidalee      JUNGLE         25   16    0.6400
# Rakan        UTILITY        25   17    0.6800
# Morgana      UTILITY        24   14    0.5833
# Graves       JUNGLE         22   13    0.5909
# Leblanc      MIDDLE         22   13    0.5909
# Irelia       MIDDLE         22   11    0.5000
# Lucian       BOTTOM         21   11    0.5238
# Elise        JUNGLE         21   13    0.6190
# Darius       TOP            21    8    0.3810
# Akali        MIDDLE         21    6    0.2857
# Vex          MIDDLE         21   10    0.4762
# Sylas        MIDDLE         21   10    0.4762
# Yorick       TOP            21   13    0.6190
# Pyke         UTILITY        20    9    0.4500
# Maokai       JUNGLE         20    8    0.4000
# Fiora        TOP            20    8    0.4000
# Karma        UTILITY        19    8    0.4211
# Malphite     TOP            19    6    0.3158
# Shaco        JUNGLE         19   10    0.5263
# Senna        UTILITY        19    4    0.2105
# Zac          JUNGLE         19    8    0.4211
# Viego        JUNGLE         19    8    0.4211
# Veigar       MIDDLE         18   10    0.5556
# Garen        TOP            18   10    0.5556
# Viktor       MIDDLE         18   11    0.6111
# Nasus        TOP            18    8    0.4444
# Gangplank    TOP            18   11    0.6111
# Sett         TOP            18    5    0.2778
# Leona        UTILITY        17    7    0.4118
# Katarina     MIDDLE         17    8    0.4706
# Sivir        BOTTOM         17    9    0.5294
# Kayn         JUNGLE         17    6    0.3529
# Swain        UTILITY        16   11    0.6875
# Azir         MIDDLE         16    7    0.4375

# %% [markdown]
# # G_14의 포지션별 챔피언의 골드량 데이터 만들기

# %%
mean_df = my_df2.groupby(['CHAMPIONNAME','TEAMPOSITION'])[['G_14']].mean().round(2).rename(columns={'WIN':'CNT'})

# %%
mean_df.sort_values(by=['G_14'], ascending=False)[:60]
# Out:
#                                G_14
# CHAMPIONNAME TEAMPOSITION
# Draven       TOP           10711.00
# Neeko        TOP            7671.00
# Swain        MIDDLE         7182.00
# Caitlyn      TOP            6778.00
# Gwen         JUNGLE         6743.00
# Sejuani      MIDDLE         6599.00
# Sion         BOTTOM         6570.00
# Karthus      JUNGLE         6540.00
# Belveth      JUNGLE         6434.50
# LeeSin       MIDDLE         6363.00
# Neeko        UTILITY        6349.00
# Kayle        MIDDLE         6313.00
# Orianna      BOTTOM         6305.00
# Kled         MIDDLE         6281.00
# Udyr         TOP            6281.00
# Draven       BOTTOM         6179.23
# Nocturne     TOP            6165.00
# Graves       TOP            6160.67
# Twitch       BOTTOM         6038.00
# Velkoz       MIDDLE         6022.00
# Swain        TOP            6014.00
# RekSai       JUNGLE         5937.33
# Ornn         JUNGLE         5935.00
# AurelionSol  BOTTOM         5899.00
# Nocturne     JUNGLE         5881.46
# Shen         JUNGLE         5845.00
# Jayce        MIDDLE         5815.60
# Olaf         JUNGLE         5776.50
# Lucian       TOP            5767.00
# Kled         TOP            5762.80
# Viktor       TOP            5754.00
# Nidalee      JUNGLE         5751.40
# Shyvana      TOP            5749.00
# Samira       BOTTOM         5743.65
# Poppy        TOP            5731.00
# Yasuo        TOP            5726.20
# Tryndamere   TOP            5720.62
# XinZhao      JUNGLE         5706.67
# Renekton     MIDDLE         5698.25
# Illaoi       MIDDLE         5694.50
# Khazix       JUNGLE         5687.40
# MissFortune  BOTTOM         5686.40
# Riven        MIDDLE         5669.00
# Lillia       JUNGLE         5665.00
# Varus        MIDDLE         5644.00
# Evelynn      JUNGLE         5643.58
# Heimerdinger TOP            5594.33
# Swain        BOTTOM         5572.00
# Kaisa        BOTTOM         5570.87
# Sion         TOP            5566.56
# Graves       JUNGLE         5562.77
# Irelia       TOP            5530.25
# Rumble       MIDDLE         5524.50
# Irelia       MIDDLE         5524.45
# Caitlyn      BOTTOM         5522.38
# Trundle      JUNGLE         5496.50
# Pantheon     JUNGLE         5495.33
# Hecarim      JUNGLE         5492.22
# Teemo        JUNGLE         5489.00
# Blitzcrank   MIDDLE         5481.00

# %%
mean_winrate_df=pd.merge(mean_df,cnt_win_df,on=['CHAMPIONNAME','TEAMPOSITION'])

# %%
mean_winrate_df.sort_values(by=['G_14'], ascending=False)[:60]
# Out:
#                                G_14  CNT  WIN  win_rate
# CHAMPIONNAME TEAMPOSITION
# Draven       TOP           10711.00    1    1    1.0000
# Neeko        TOP            7671.00    1    1    1.0000
# Swain        MIDDLE         7182.00    1    0    0.0000
# Caitlyn      TOP            6778.00    1    1    1.0000
# Gwen         JUNGLE         6743.00    1    1    1.0000
# Sejuani      MIDDLE         6599.00    1    0    0.0000
# Sion         BOTTOM         6570.00    1    1    1.0000
# Karthus      JUNGLE         6540.00    1    1    1.0000
# Belveth      JUNGLE         6434.50    2    1    0.5000
# LeeSin       MIDDLE         6363.00    1    0    0.0000
# Neeko        UTILITY        6349.00    1    1    1.0000
# Kayle        MIDDLE         6313.00    1    1    1.0000
# Orianna      BOTTOM         6305.00    1    1    1.0000
# Kled         MIDDLE         6281.00    1    1    1.0000
# Udyr         TOP            6281.00    1    0    0.0000
# Draven       BOTTOM         6179.23   13    6    0.4615
# Nocturne     TOP            6165.00    2    2    1.0000
# Graves       TOP            6160.67    3    2    0.6667
# Twitch       BOTTOM         6038.00    1    1    1.0000
# Velkoz       MIDDLE         6022.00    1    1    1.0000
# Swain        TOP            6014.00    1    1    1.0000
# RekSai       JUNGLE         5937.33    3    2    0.6667
# Ornn         JUNGLE         5935.00    1    0    0.0000
# AurelionSol  BOTTOM         5899.00    1    1    1.0000
# Nocturne     JUNGLE         5881.46   13    9    0.6923
# Shen         JUNGLE         5845.00    1    1    1.0000
# Jayce        MIDDLE         5815.60   10    7    0.7000
# Olaf         JUNGLE         5776.50    2    2    1.0000
# Lucian       TOP            5767.00    2    1    0.5000
# Kled         TOP            5762.80    5    2    0.4000
# Viktor       TOP            5754.00    1    1    1.0000
# Nidalee      JUNGLE         5751.40   25   16    0.6400
# Shyvana      TOP            5749.00    1    0    0.0000
# Samira       BOTTOM         5743.65   31   12    0.3871
# Poppy        TOP            5731.00    3    3    1.0000
# Yasuo        TOP            5726.20    5    1    0.2000
# Tryndamere   TOP            5720.62    8    4    0.5000
# XinZhao      JUNGLE         5706.67    9    3    0.3333
# Renekton     MIDDLE         5698.25    4    2    0.5000
# Illaoi       MIDDLE         5694.50    2    1    0.5000
# Khazix       JUNGLE         5687.40   10    6    0.6000
# MissFortune  BOTTOM         5686.40   15    9    0.6000
# Riven        MIDDLE         5669.00    1    0    0.0000
# Lillia       JUNGLE         5665.00    2    1    0.5000
# Varus        MIDDLE         5644.00    1    0    0.0000
# Evelynn      JUNGLE         5643.58   12    8    0.6667
# Heimerdinger TOP            5594.33    3    2    0.6667
# Swain        BOTTOM         5572.00    1    1    1.0000
# Kaisa        BOTTOM         5570.87   71   41    0.5775
# Sion         TOP            5566.56    9    5    0.5556
# Graves       JUNGLE         5562.77   22   13    0.5909
# Irelia       TOP            5530.25   16    9    0.5625
# Rumble       MIDDLE         5524.50    8    2    0.2500
# Irelia       MIDDLE         5524.45   22   11    0.5000
# Caitlyn      BOTTOM         5522.38   52   22    0.4231
# Trundle      JUNGLE         5496.50    2    2    1.0000
# Pantheon     JUNGLE         5495.33    3    1    0.3333
# Hecarim      JUNGLE         5492.22    9    5    0.5556
# Teemo        JUNGLE         5489.00    2    2    1.0000
# Blitzcrank   MIDDLE         5481.00    1    0    0.0000

# %% [markdown]
# # import matplotlib.pyplot as plt

# %%
my_df =df[df.gameId =='KR_6258040492']

# %%
my_df.columns
# Out:
# Index(['gameId', 'gameDuration', 'gameVersion', 'summonerName',
#        'summonerLevel', 'participantId', 'championName', 'champExperience',
#        'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists',
#        'totalDamageDealtToChampions', 'totalDamageTaken', 'g_5', 'g_6', 'g_7',
#        'g_8', 'g_9', 'g_10', 'g_11', 'g_12', 'g_13', 'g_14', 'g_15', 'g_16',
#        'g_17', 'g_18', 'g_19', 'g_20', 'g_21', 'g_22', 'g_23', 'g_24', 'g_25'],
#       dtype='object')

# %%
my_df.set_index('summonerName', inplace=True)

# %%
damage =my_df['totalDamageDealtToChampions']

# %%
damage
# Out:
# summonerName
# sherlocklovejohn    31064
# 염오쩌둥                33171
# anather5337         40046
# jungwon99           33466
# 롤린이떴다               42697
# Jeongsunha          37051
# 구철통                 40872
# 탈론 명인               19155
# 149cm               28281
# 아이언 구렁텅이            11628
# Name: totalDamageDealtToChampions, dtype: int64

# %%
# 폰트 조정
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font) # 윈도우

# %%
plt.plot(damage,color = 'blue',marker='v')

# %%
yticks_interval = 5000

maxlim = int((damage.max()/yticks_interval+1))* yticks_interval
values = np.arange(0,maxlim+1, yticks_interval)
plt.yticks(values,['%s'%format(val,',')for val in values])# 리스트 컴프리헨션

plt.grid(True)
plt.title('딜량 그래프')
plt.xlabel('소환사 명')
plt.ylabel('딜량 그래프')

plt.xticks(rotation=45)
plt.plot(damage,color = 'blue' , marker='v')

# %%
tmp_df = df[['teamPosition','totalDamageDealtToChampions','totalDamageTaken','g_15']]

# %%
tmp_df = tmp_df[~tmp_df.teamPosition.isna()]

# %%
my_tmp = tmp_df[tmp_df.teamPosition=='JUNGLE']

# %%
xdata=my_tmp.g_15
ydata=my_tmp.totalDamageDealtToChampions

# %%
plt.figure()
plt.plot(xdata,ydata,color='r',marker='o', linestyle='None')
plt.xlabel('15분 골드')
plt.ylabel('딜량')
plt.title('딜량에 따른 15분 골드 획득량 관계')
plt.grid(True)

# %%
ydata2 = my_tmp.totalDamageTaken

# %%
plt.figure()
plt.plot(xdata,ydata,color='r',marker='^', linestyle='None')
plt.plot(xdata,ydata2, color='b',marker='v',linestyle='None')
plt.xlabel('15분 골드')
plt.ylabel('딜량')
plt.title('딜량에 따른 15분 골드 획득량 관계')
plt.grid(True)

# %%
group_df = tmp_df.groupby('teamPosition').mean().round().reset_index()

# %%
group_df
# Out:
#   teamPosition  totalDamageDealtToChampions  totalDamageTaken    g_15
# 0                                    1811.0            2435.0   907.0
# 1       BOTTOM                      19976.0           18767.0  5604.0
# 2       JUNGLE                      17315.0           29334.0  5566.0
# 3       MIDDLE                      19896.0           22172.0  5275.0
# 4          TOP                      19373.0           26709.0  5216.0
# 5      UTILITY                      11367.0           17112.0  4073.0

# %%
plt.figure()
plt.bar(group_df.teamPosition, group_df.totalDamageDealtToChampions, color = ['b','g','r','c','m'])
plt.xlabel('포지션')
plt.ylabel('딜량')
plt.title('포지션별 평균 딜량')
mean_val = group_df.totalDamageDealtToChampions.mean()
plt.axhline(y=mean_val, color = 'r', linestyle = 'dashed')

# %%
group_df.set_index('teamPosition', inplace=True)

# %%
group_df
# Out:
#               totalDamageDealtToChampions  totalDamageTaken    g_15
# teamPosition
#                                    1811.0            2435.0   907.0
# BOTTOM                            19976.0           18767.0  5604.0
# JUNGLE                            17315.0           29334.0  5566.0
# MIDDLE                            19896.0           22172.0  5275.0
# TOP                               19373.0           26709.0  5216.0
# UTILITY                           11367.0           17112.0  4073.0

# %%
plt.figure()
plt.pie(group_df.loc['BOTTOM'], labels = ['딜량','받은 피해량','15분골드'], shadow =True, autopct='%1.1f%%', explode = (0,0,0.1))
plt.grid(True)
plt.legend(loc = 7)
plt.title('파이차트')
# Out:
# Text(0.5, 1.0, '파이차트')
