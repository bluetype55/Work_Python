# %%
import requests
from tqdm import tqdm
import pandas as pd
import numpy as np
import time
import my_utils as mu
import math
import random
import imp
imp.reload(mu)
tqdm.pandas()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4412\3360147383.py:9: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %%
mu.auto_insert_my(100)

# %%
url =f'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6403267998/timeline?api_key={mu.riot_api_key}'
res2 = requests.get(url).json()
res2
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6403267998',
#   'participants': ['UxFQFPHxS5C4-qTKAIkS-5kjlODxBSe22f046ORKe3KWseQy63TEsjH93LoF59Ll3VNZxVOR2HA8XQ',
#    'lh4JjqkvX7z0ajLvQC9T7Z6oCkR_HRWgnFD7OpeKJQlVaEr0eDv20QuBDgpmnqsQbkK9XHDp-aqcHA',
#    'JORV2vvcBD5oSin9yIGMfvuD2TQ59TyBuW0U7_DU-5EExPVJzjLJvfljfz32_Quon1W8Ic46IM3KRg',
#    'XQFn9s-XRhY-uVOY_YZNibG7x0iwkrMs_OuNVbK70IAdH7wsBUbT8ujYqkduRhmu2lRPu_HLmktvKg',
#    'R9b6mxj6pUaPN9baljzDoJ8rsH-YscgMCQpMH5UrWDsbYKbH5rTLx8sHcSYuGsKwCTNhUEwKMlPRsA',
#    'gqq2tCjG0oWTmiX3bEbfjz1dw5_i4qTaevLcqS562W1290-jiB4W-x-mjHZvyZPZJNt3oauu9uQO3A',
#    'agUVWl46sn9zYQm7hfC-YKI7i2BOnakGI1n9p7nAJ0NvQucaLiQ_tjLyBsI1zk9SU9nLzuW3_EnKzg',
#    'MoPn7hedmE6IW2rlZzOAeN6NSIAHVNYV88-62CThjVBqOfEfjk5ka_tIJ5NMPVJC6xi86jB0owhkbA',
#    'GSK6CymmWDodzWLGzDY2DThAfNH6T0YhQ01OOWj20AIBHaP7mmuOw4KXjFPQuSpVOwioSzWvCcyjaQ',
#    'f0LGa61ltmzt1SvtBiUNRBj4t7Wpp4vJlTphkyHogUJEjgVpkivc1OpmNAdJmt340vzL4B2gpZMfow']},
#  'info': {'frameInterval': 60000,
# ...

# %%
res2['info'].keys()
# Out:
# dict_keys(['frameInterval', 'frames', 'gameId', 'participants'])

# %%
# Out:
# [{'bans': [{'championId': 60, 'pickTurn': 1},
#    {'championId': 111, 'pickTurn': 2},
#    {'championId': 22, 'pickTurn': 3},
#    {'championId': 238, 'pickTurn': 4},
#    {'championId': 82, 'pickTurn': 5}],
#   'objectives': {'baron': {'first': True, 'kills': 1},
#    'champion': {'first': False, 'kills': 31},
#    'dragon': {'first': True, 'kills': 2},
#    'inhibitor': {'first': False, 'kills': 0},
#    'riftHerald': {'first': True, 'kills': 2},
#    'tower': {'first': True, 'kills': 5}},
#   'teamId': 100,
#   'win': False},
#  {'bans': [{'championId': 53, 'pickTurn': 6},
#    {'championId': 22, 'pickTurn': 7},
#    {'championId': 78, 'pickTurn': 8},
#    {'championId': 39, 'pickTurn': 9},
#    {'championId': 68, 'pickTurn': 10}],
#   'objectives': {'baron': {'first': False, 'kills': 1},
#    'champion': {'first': True, 'kills': 32},
#    'dragon': {'first': False, 'kills': 3},
#    'inhibitor': {'first': True, 'kills': 1},
#    'riftHerald': {'first': False, 'kills': 0},
# ...

# %%
url = f'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6385261910?api_key={mu.riot_api_key}'
res = requests.get(url).json()
res
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6385261910',
#   'participants': ['6zqMOLx1J82Hr6IumwqyMoJndJVB-qSWUsV1ZPGsSk7m901dQAyhhssvR2BT-0hS3gOWC5DTZXGyIQ',
#    'XNkblbm9jNkK9-RjHlrsib35nFLgxzceq6BoNZkPbr4TzYkaaCEOwTvxqep_fMtpdI1mDhFG9Tcq5A',
#    '-wzvsSsQ-pvOJ98PSSRH8rtGBQyRUD0RVV-Ici3LQXC9oEu1PBnicLL2_RJIAYWxub3JUDB7aEGslQ',
#    'F_fKg1jKyLqsMTgUv25BimFOl5GY7oFmAZruWLWsI0o64JhfiZFIe_W-PwGzq_lj0B05GBwV3wxayg',
#    'sb9BGMxfs04B7JtPHq0sbviklVOomQCBGqXUOWOSYcoXo1Pp0rf12qSsiOIEcIq7yoCT20MrcogjIg',
#    '6hq5KqnQi0y-jvoP7id6W6BzN4lUK2eurztMd7erols3BTTV391EE6GXcEC8dAMLAAaJyL_E7rU2CA',
#    'RhcK-h8klwzvbO1w1Zzuw17imbLnwNMoH226g6_0rNxMKlGMk9VrIQjMox5KaQYYdFiipgJ5au-yNA',
#    'dJQF4iAzH3xPadsPB9BiWTrIbTqZA3ln7jXQMZaVAHJHp6IV7NRpbLPqaOf2lKlhulac0hfWimjCvw',
#    'q041DrVHAs1yz8jqn3TJ6yle8QXHXkUoq3Fu7mRJrPKRiEfsbWWfcBGVk5dtuJJtNzYrZWH9HfonZw',
#    '9N3YQ_uuLY_9EmOx8r9qipPPT0vuVmIiUUU1cbGeAsMYQJspOxkkkQjkYj6Pgk_cQvJo4bRiOaiHqw']},
#  'info': {'gameCreation': 1677588797204,
# ...

# %%
res['info'].keys()
# Out:
# dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
res['info']['teams'][0][]
# Out:
# {'bans': [{'championId': 60, 'pickTurn': 1},
#   {'championId': 111, 'pickTurn': 2},
#   {'championId': 22, 'pickTurn': 3},
#   {'championId': 238, 'pickTurn': 4},
#   {'championId': 82, 'pickTurn': 5}],
#  'objectives': {'baron': {'first': True, 'kills': 1},
#   'champion': {'first': False, 'kills': 31},
#   'dragon': {'first': True, 'kills': 2},
#   'inhibitor': {'first': False, 'kills': 0},
#   'riftHerald': {'first': True, 'kills': 2},
#   'tower': {'first': True, 'kills': 5}},
#  'teamId': 100,
#  'win': False}

# %%
res['info']['participants'][0]['firstBloodKill']
# Out:
# False

# %%
res['info']['participants'][0]['firstTowerKill']
# Out:
# False

# %%
teamPosition_list=[]
for i in range(10):
    teamPosition = res['info']['participants'][i]['lane']
    teamPosition_list.append(teamPosition)

# %%
teamPosition_list
# Out:
# ['TOP',
#  'JUNGLE',
#  'MIDDLE',
#  'BOTTOM',
#  'BOTTOM',
#  'TOP',
#  'JUNGLE',
#  'BOTTOM',
#  'BOTTOM',
#  'MIDDLE']

# %%
res['info']['participants'][0]['teamPosition']
# Out:
# 'TOP'

# %%
conn= mu.connect_mysql('icia')
query = "select gameId from lol_datas where teamPosition =''"
gameIds_dict=mu.mysql_execute_dict(query,conn)

# %%
gameIds_dict
# Out:
# [{'gameId': 'KR_6366151398'}]

# %%
conn= mu.connect_mysql('icia')
query = "select gameId from lol_datas where teamPosition =''"
gameIds_dict=mu.mysql_execute_dict(query,conn)
for i in range(len(gameIds_dict)):
    gameId=gameIds_dict[i]['gameId']
    query2 = f"delete from lol_datas where gameId ={repr(gameId)}"
    print(query2)
    mu.mysql_execute(query2,conn)
conn.commit()
# Out:
# delete from lol_datas where gameId ='KR_6366151398'
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4412\3934012498.py in <module>
#       6     query2 = f"delete from lol_datas where gameId ={repr(gameId)}"
#       7     print(query2)
# ----> 8     mu.mysql_execute(query2,conn)
#       9 conn.commit()
#
# ~\Work_Python\my_utils.py in mysql_execute(query, conn)
#      55 def mysql_execute(query, conn):
#      56     cursor_mysql = conn.cursor()
# ---> 57     cursor_mysql.execute(query)
#      58     result = cursor_mysql.fetchall()
#      59     return result
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ...

# %%
# Out:
# delete from lol_datas where gameId ='KR_6366151398'
# <bound method Connection.commit of <pymysql.connections.Connection object at 0x000001EA23B15430>>
